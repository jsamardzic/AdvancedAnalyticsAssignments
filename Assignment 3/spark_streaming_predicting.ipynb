# %%
import threading

# Helper thread to avoid the Spark StreamingContext from blocking Jupyter
        
class StreamingThread(threading.Thread):
    def __init__(self, ssc):
        super().__init__()
        self.ssc = ssc
    def run(self):
        self.ssc.start()
        self.ssc.awaitTermination()
    def stop(self):
        print('----- Stopping... this may take a few seconds -----')
        self.ssc.stop(stopSparkContext=False, stopGraceFully=True)

# %%
sc
# Out:
# <SparkContext master=local[*] appName=PySparkShell>

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://ACER:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>PySparkShell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
import numpy as np
import pandas as pd
import pyspark
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from pyspark.ml import Pipeline # pipeline to transform data
from pyspark.sql import SparkSession # to initiate spark
from pyspark.ml.linalg import Vectors # to allow us to work with VectorAssembler
from pyspark.ml.feature import VectorAssembler # to combine our feature columns to pass to LogisticRegression model
from pyspark.sql.types import FloatType
from pyspark.ml.feature import RegexTokenizer # tokenizer
from pyspark.ml.feature import HashingTF, IDF, IDFModel # vectorizer
from pyspark.ml.feature import StopWordsRemover # to remove stop words
from pyspark.ml.classification import LogisticRegression, LogisticRegressionModel # ml model
from pyspark.ml.evaluation import BinaryClassificationEvaluator # to evaluate the model

from pyspark.streaming import StreamingContext
from pyspark.sql import Row
from pyspark.sql.functions import udf, struct, array, col, lit
from pyspark.sql.types import StringType

from pyspark.ml.pipeline import PipelineModel

# %%
## YOUR MODEL PATH HERE ##
model_path = "C:\\Users\\Dillon\\Desktop\\spark\\notebooks\\models"

# %%
globals()['models_loaded'] = False
globals()['my_model'] = None

def process(time, rdd):
    if rdd.isEmpty():
        return
    
    print("========= %s =========" % str(time))
    
    # Convert to data frame
    df = spark.read.json(rdd)
    
    # Load in the model if not yet loaded:
    if not globals()['models_loaded']:
        # load in your models here
        globals()['my_model'] = PipelineModel.load(model_path) 
        globals()['models_loaded'] = True
        
    # Predicting using the loaded model:
    
    df_result = globals()['my_model'].transform(df)
    df_result.select(["title", "votes", "comments", "probability", "prediction", "frontpage"]).show()

# %%
ssc = StreamingContext(sc, 10)
# Out:
# C:\Users\Dillon\Desktop\spark\spark-3.5.1-bin-hadoop3\python\pyspark\streaming\context.py:72: FutureWarning: DStream is deprecated as of Spark 3.4.0. Migrate to Structured Streaming.
#   warnings.warn(

# %%
lines = ssc.socketTextStream("seppe.net", 7778)
lines.foreachRDD(process)

# %%
ssc_t = StreamingThread(ssc)
ssc_t.start()
# Out:
# ========= 2024-05-23 16:14:40 =========
# +--------------------+-----+--------+--------------------+----------+---------+
# |               title|votes|comments|         probability|prediction|frontpage|
# +--------------------+-----+--------+--------------------+----------+---------+
# |Impact of Design ...|    1|       0|[0.96898402799738...|       0.0|    false|
# |Palestinian state...|    1|       0|[0.96514873172688...|       0.0|    false|
# +--------------------+-----+--------+--------------------+----------+---------+
#
# ========= 2024-05-23 16:14:50 =========
# +--------------------+-----+--------+--------------------+----------+---------+
# |               title|votes|comments|         probability|prediction|frontpage|
# +--------------------+-----+--------+--------------------+----------+---------+
# |China's latest an...|    1|       0|[0.96041286055183...|       0.0|    false|
# |How Big Is Taylor...|    1|       0|[0.96377734611366...|       0.0|    false|
# |Reflections on my...|    2|       0|[0.91697599964288...|       0.0|    false|
# |New code-focused ...|    4|       0|[0.63650914136536...|       0.0|    false|
# |Steps to Overcome...|    1|       0|[0.97195879809021...|       0.0|    false|
# +--------------------+-----+--------+--------------------+----------+---------+
#
# ========= 2024-05-23 16:15:00 =========
# +--------------------+-----+--------+--------------------+----------+---------+
# |               title|votes|comments|         probability|prediction|frontpage|
# +--------------------+-----+--------+--------------------+----------+---------+
# |Azure will not ch...|    1|       0|[0.97973430650549...|       0.0|    false|
# |Save on your AWS ...|    1|       0|[0.97223399640737...|       0.0|    false|
# |An autonomous rob...|    1|       0|[0.86953448551581...|       0.0|    false|
# +--------------------+-----+--------+--------------------+----------+---------+
#
# ========= 2024-05-23 16:15:10 =========
# +--------------------+-----+--------+--------------------+----------+---------+
# |               title|votes|comments|         probability|prediction|frontpage|
# +--------------------+-----+--------+--------------------+----------+---------+
# |WinDirStat – Wind...|    9|       7|[0.05328112648590...|       1.0|     true|
# |real-time chatbot...|    1|       0|[0.95963667982904...|       0.0|    false|
# |An Introduction t...|    1|       0|[0.96776878656459...|       0.0|    false|
# +--------------------+-----+--------+--------------------+----------+---------+
#
# ========= 2024-05-23 16:15:20 =========
# +--------------------+-----+--------+--------------------+----------+---------+
# |               title|votes|comments|         probability|prediction|frontpage|
# +--------------------+-----+--------+--------------------+----------+---------+
# |Find Your Perfect...|    1|       0|[0.97865510022532...|       0.0|    false|
# |Were Egypt's pyra...|    1|       0|[0.97565822709749...|       0.0|    false|
# |Photographer Sues...|   16|       2|[6.94170348756331...|       1.0|     true|
# +--------------------+-----+--------+--------------------+----------+---------+
#
# ========= 2024-05-23 16:15:30 =========
# +--------------------+-----+--------+--------------------+----------+---------+
# |               title|votes|comments|         probability|prediction|frontpage|
# +--------------------+-----+--------+--------------------+----------+---------+
# |Lead Poisoning an...|    2|       0|[0.90338981646026...|       0.0|    false|
# |Drone footage sho...|    1|       0|[0.96475631712528...|       0.0|    false|
# |Show HN: Kushty B...|    1|       0|[0.98893258701021...|       0.0|    false|
# |AI token optimiza...|    1|       0|[0.98989905339098...|       0.0|    false|
# +--------------------+-----+--------+--------------------+----------+---------+
#
# ========= 2024-05-23 16:15:40 =========
# +--------------------+-----+--------+--------------------+----------+---------+
# |               title|votes|comments|         probability|prediction|frontpage|
# +--------------------+-----+--------+--------------------+----------+---------+
# |Magic UI: UI Libr...|    6|       0|[0.38347359142921...|       1.0|     true|
# |Show HN: Perfit –...|    1|       0|[0.98037479749118...|       0.0|    false|
# |Visibility into A...|    1|       0|[0.97567424489852...|       0.0|    false|
# |B-21 Raider conti...|    1|       0|[0.98433654053132...|       0.0|    false|
# +--------------------+-----+--------+--------------------+----------+---------+
#
# ========= 2024-05-23 16:15:50 =========
# +--------------------+-----+--------+--------------------+----------+---------+
# |               title|votes|comments|         probability|prediction|frontpage|
# +--------------------+-----+--------+--------------------+----------+---------+
# |BLUE_CHANNEL: THA...|    1|       0|[0.98143548404130...|       0.0|    false|
# |The Python Calend...|    1|       0|[0.96851432896362...|       0.0|    false|
# |How to find hidde...|    3|       0|[0.92758899819960...|       0.0|     true|
# +--------------------+-----+--------+--------------------+----------+---------+
#
# ========= 2024-05-23 16:16:00 =========
# +--------------------+-----+--------+--------------------+----------+---------+
# |               title|votes|comments|         probability|prediction|frontpage|
# +--------------------+-----+--------+--------------------+----------+---------+
# |Yemen's Houthis c...|    1|       0|[0.91592541735119...|       0.0|    false|
# |Design Rules for ...|    1|       0|[0.96728336273668...|       0.0|    false|
# +--------------------+-----+--------+--------------------+----------+---------+
#
# ========= 2024-05-23 16:16:10 =========
# +--------------------+-----+--------+--------------------+----------+---------+
# |               title|votes|comments|         probability|prediction|frontpage|
# +--------------------+-----+--------+--------------------+----------+---------+
# |ChatGPT: Hacking ...|    4|       0|[0.78702857638821...|       0.0|    false|
# |&udm=14 – the dis...|    7|       0|[0.13066884800356...|       1.0|     true|
# |Washington Post l...|    1|       0|[0.95259179577031...|       0.0|    false|
# +--------------------+-----+--------+--------------------+----------+---------+
#
# ========= 2024-05-23 16:16:20 =========
# +--------------------+-----+--------+--------------------+----------+---------+
# |               title|votes|comments|         probability|prediction|frontpage|
# +--------------------+-----+--------+--------------------+----------+---------+
# |Residents of Athe...|    1|       0|[0.93274569712927...|       0.0|    false|
# |One of the most u...|   10|       0|[0.00967574676965...|       1.0|     true|
# |Rocket Lab – spac...|    1|       0|[0.96160016101169...|       0.0|    false|
# |Google Workspace ...|    1|       0|[0.97790233187893...|       0.0|    false|
# +--------------------+-----+--------+--------------------+----------+---------+
#
# ========= 2024-05-23 16:16:30 =========
# +--------------------+-----+--------+--------------------+----------+---------+
# |               title|votes|comments|         probability|prediction|frontpage|
# +--------------------+-----+--------+--------------------+----------+---------+
# |How to Run Comple...|    1|       0|[0.98760513571311...|       0.0|    false|
# |Lizardman's Constant|    1|       0|[0.97248535871390...|       0.0|    false|
# +--------------------+-----+--------+--------------------+----------+---------+
#
# ========= 2024-05-23 16:16:40 =========
# +--------------------+-----+--------+--------------------+----------+---------+
# |               title|votes|comments|         probability|prediction|frontpage|
# +--------------------+-----+--------+--------------------+----------+---------+
# |Building C/OpenGL...|    2|       0|[0.94091488254126...|       0.0|    false|
# |Haptic Source-eff...|    1|       0|[0.95358031523373...|       0.0|    false|
# |A Go framework fo...|    1|       0|[0.98163128150248...|       0.0|    false|
# |Best Practices Co...|    1|       0|[0.97860730718797...|       0.0|    false|
# +--------------------+-----+--------+--------------------+----------+---------+
#
# ========= 2024-05-23 16:16:50 =========
# +-----------------+-----+--------+--------------------+----------+---------+
# |            title|votes|comments|         probability|prediction|frontpage|
# +-----------------+-----+--------+--------------------+----------+---------+
# |Project Awakening|    1|       0|[0.98077390784462...|       0.0|    false|
# |Cot-Caught Merger|    2|       0|[0.94728183443392...|       0.0|    false|
# |   No Wrong Doors|    1|       0|[0.98017759598134...|       0.0|    false|
# +-----------------+-----+--------+--------------------+----------+---------+
# ========= 2024-05-23 16:17:00 =========
# +--------------------+-----+--------+--------------------+----------+---------+
# |               title|votes|comments|         probability|prediction|frontpage|
# +--------------------+-----+--------+--------------------+----------+---------+
# |Show HN: Can GPT ...|    1|       0|[0.98023619718023...|       0.0|    false|
# |Oxidizing OCaml w...|    2|       0|[0.91846809175416...|       0.0|    false|
# +--------------------+-----+--------+--------------------+----------+---------+
#
# ========= 2024-05-23 16:17:10 =========
# +--------------------+-----+--------+--------------------+----------+---------+
# |               title|votes|comments|         probability|prediction|frontpage|
# +--------------------+-----+--------+--------------------+----------+---------+
# |(1) Confessions o...|    2|       0|[0.90859683229771...|       0.0|    false|
# |Can Scarlett Joha...|    1|       0|[0.97945156358759...|       0.0|    false|
# |OpenAI, WSJ Owner...|   26|       4|[2.22247916958501...|       1.0|     true|
# +--------------------+-----+--------+--------------------+----------+---------+
#
# ========= 2024-05-23 16:18:20 =========
# +--------------------+-----+--------+--------------------+----------+---------+
# |               title|votes|comments|         probability|prediction|frontpage|
# +--------------------+-----+--------+--------------------+----------+---------+
# |Default Sort Orde...|    1|       0|[0.95622221536540...|       0.0|    false|
# |Zen and the Art o...|    2|       0|[0.93520844716958...|       0.0|    false|
# |    Jab, Cross, Hook|    1|       0|[0.97276894155323...|       0.0|    false|
# +--------------------+-----+--------+--------------------+----------+---------+
#
# ========= 2024-05-23 16:18:30 =========
# +--------------------+-----+--------+--------------------+----------+---------+
# |               title|votes|comments|         probability|prediction|frontpage|
# +--------------------+-----+--------+--------------------+----------+---------+
# |           Eudaemons|    1|       0|[0.97394841397139...|       0.0|    false|
# |World Page Speed ...|    1|       0|[0.94426300571063...|       0.0|    false|
# |Show HN: Cutting-...|    1|       0|[0.98354420217660...|       0.0|    false|
# |Keep a Developer'...|    1|       0|[0.98469548243980...|       0.0|    false|
# +--------------------+-----+--------+--------------------+----------+---------+
#
# ========= 2024-05-23 16:18:40 =========
# +--------------------+-----+--------+--------------------+----------+---------+
# |               title|votes|comments|         probability|prediction|frontpage|
# +--------------------+-----+--------+--------------------+----------+---------+
# |Nvidia chief Huan...|    5|       0|[0.37764789168807...|       1.0|     true|
# |Why Stream Proces...|    1|       0|[0.96707925517283...|       0.0|    false|
# +--------------------+-----+--------+--------------------+----------+---------+
#
# ========= 2024-05-23 16:18:50 =========
# +--------------------+-----+--------+--------------------+----------+---------+
# |               title|votes|comments|         probability|prediction|frontpage|
# +--------------------+-----+--------+--------------------+----------+---------+
# |&udm=14 – the dis...|    2|       0|[0.91895718394281...|       0.0|    false|
# |The rally test th...|    1|       0|[0.97734550148957...|       0.0|    false|
# +--------------------+-----+--------+--------------------+----------+---------+
#
# ========= 2024-05-23 16:19:00 =========
# +--------------------+-----+--------+--------------------+----------+---------+
# |               title|votes|comments|         probability|prediction|frontpage|
# +--------------------+-----+--------+--------------------+----------+---------+
# |Rust's iterators ...|    1|       0|[0.96552129272679...|       0.0|    false|
# |Android's upgrade...|    2|       0|[0.97084037066507...|       0.0|    false|
# |   Shm-Reduplication|    1|       0|[0.97366867136774...|       0.0|    false|
# +--------------------+-----+--------+--------------------+----------+---------+
#
# ========= 2024-05-23 16:19:10 =========
# +--------------------+-----+--------+--------------------+----------+---------+
# |               title|votes|comments|         probability|prediction|frontpage|
# +--------------------+-----+--------+--------------------+----------+---------+
# |SignSaboteur: for...|    1|       0|[0.95363355124705...|       0.0|    false|
# |Fallout Apocrypha...|    1|       0|[0.96742623587740...|       0.0|    false|
# +--------------------+-----+--------+--------------------+----------+---------+
#
# ========= 2024-05-23 16:19:20 =========
# +--------------------+-----+--------+--------------------+----------+---------+
# |               title|votes|comments|         probability|prediction|frontpage|
# +--------------------+-----+--------+--------------------+----------+---------+
# |Europe Sees Signs...|    1|       0|[0.95196099079801...|       0.0|    false|
# | Abload Goes Offline|    1|       0|[0.96696923236236...|       0.0|    false|
# |Finding Love Opti...|    2|       0|[0.95755036646862...|       0.0|    false|
# |         The Reddits|    1|       0|[0.98427923370465...|       0.0|    false|
# +--------------------+-----+--------+--------------------+----------+---------+
#
# ========= 2024-05-23 16:19:30 =========
# +--------------------+-----+--------+--------------------+----------+---------+
# |               title|votes|comments|         probability|prediction|frontpage|
# +--------------------+-----+--------+--------------------+----------+---------+
# |A Fur Suit Design...|    1|       0|[0.98707077973507...|       0.0|    false|
# |Learn you a Haske...|    3|       0|[0.90877796702763...|       0.0|    false|
# |     DuckDuckGo Down|   20|       8|[1.01292623320522...|       1.0|     true|
# +--------------------+-----+--------+--------------------+----------+---------+
#
# ========= 2024-05-23 16:19:40 =========
# +--------------------+-----+--------+--------------------+----------+---------+
# |               title|votes|comments|         probability|prediction|frontpage|
# +--------------------+-----+--------+--------------------+----------+---------+
# |Why Revolut is as...|    1|       0|[0.97577713562080...|       0.0|    false|
# |Microsoft to star...|    1|       0|[0.95353034691993...|       0.0|    false|
# |What Happened to ...|   38|      22|[4.73603145881714...|       1.0|     true|
# +--------------------+-----+--------+--------------------+----------+---------+
#
# ========= 2024-05-23 16:19:50 =========
# +--------------------+-----+--------+--------------------+----------+---------+
# |               title|votes|comments|         probability|prediction|frontpage|
# +--------------------+-----+--------+--------------------+----------+---------+
# |Designing a keybo...|    1|       0|[0.97976484248906...|       0.0|    false|
# |Blitzed 100 Books...|    1|       0|[0.97264049285798...|       0.0|    false|
# |Testing Considera...|    4|       0|[0.79859985925485...|       0.0|    false|
# +--------------------+-----+--------+--------------------+----------+---------+
#
# ========= 2024-05-23 16:20:00 =========
# +--------------------+-----+--------+--------------------+----------+---------+
# |               title|votes|comments|         probability|prediction|frontpage|
# +--------------------+-----+--------+--------------------+----------+---------+
# |       Is Bing Down?|    3|       0|[0.88937853119562...|       0.0|    false|
# |Transforming webs...|    1|       0|[0.92638576799477...|       0.0|    false|
# |Microsoft making ...|    2|       0|[0.95970705167678...|       0.0|    false|
# +--------------------+-----+--------+--------------------+----------+---------+
#
# ========= 2024-05-23 16:20:10 =========
# +--------------------+-----+--------+--------------------+----------+---------+
# |               title|votes|comments|         probability|prediction|frontpage|
# +--------------------+-----+--------+--------------------+----------+---------+
# |Sam Altman's Scar...|    1|       0|[0.98085057088760...|       0.0|    false|
# |Vendor Kernels, B...|    1|       0|[0.97972785435413...|       0.0|    false|
# |the US's first hy...|    1|       0|[0.94757805649636...|       0.0|    false|
# +--------------------+-----+--------+--------------------+----------+---------+
# ========= 2024-05-23 16:20:20 =========
# +--------------------+-----+--------+--------------------+----------+---------+
# |               title|votes|comments|         probability|prediction|frontpage|
# +--------------------+-----+--------+--------------------+----------+---------+
# |Getting Wiser fro...|    1|       0|[0.97431307897922...|       0.0|    false|
# |AutoBlink: Monito...|    2|       0|[0.85361326432267...|       0.0|    false|
# |Bypassed app down...|    1|       0|[0.95976334163265...|       0.0|    false|
# +--------------------+-----+--------+--------------------+----------+---------+
#
# ========= 2024-05-23 16:20:30 =========
# +--------------------+-----+--------+--------------------+----------+---------+
# |               title|votes|comments|         probability|prediction|frontpage|
# +--------------------+-----+--------+--------------------+----------+---------+
# |Evaluating a Cont...|    3|       0|[0.92655599541029...|       0.0|     true|
# |The Essentials of...|    1|       0|[0.94375267199331...|       0.0|    false|
# |The Klingon Progr...|    1|       0|[0.95776142487613...|       0.0|    false|
# +--------------------+-----+--------+--------------------+----------+---------+
#
# ========= 2024-05-23 16:20:40 =========
# +--------------------+-----+--------+--------------------+----------+---------+
# |               title|votes|comments|         probability|prediction|frontpage|
# +--------------------+-----+--------+--------------------+----------+---------+
# |Your Transformer ...|    4|       0|[0.67939196496916...|       0.0|     true|
# |Show HN: Novops –...|    1|       0|[0.98084188562055...|       0.0|    false|
# +--------------------+-----+--------+--------------------+----------+---------+
#
# ========= 2024-05-23 16:20:50 =========
# +--------------------+-----+--------+--------------------+----------+---------+
# |               title|votes|comments|         probability|prediction|frontpage|
# +--------------------+-----+--------+--------------------+----------+---------+
# |Nvidia will now m...|    1|       0|[0.97707601297655...|       0.0|    false|
# |Truecaller and Mi...|    1|       0|[0.97374341442486...|       0.0|    false|
# |Neuralink's First...|    1|       0|[0.96139180034029...|       0.0|    false|
# +--------------------+-----+--------+--------------------+----------+---------+
#
# ========= 2024-05-23 16:21:00 =========
# +--------------------+-----+--------+--------------------+----------+---------+
# |               title|votes|comments|         probability|prediction|frontpage|
# +--------------------+-----+--------+--------------------+----------+---------+
# |The ICC Arrest Wa...|    1|       0|[0.96559415320009...|       0.0|    false|
# |How to hold your ...|    1|       0|[0.98321061987308...|       0.0|    false|
# |Does Cloudflare a...|    2|       0|[0.89865544000869...|       0.0|    false|
# |           Libmatoya|    1|       0|[0.97538412103131...|       0.0|    false|
# +--------------------+-----+--------+--------------------+----------+---------+
#
# ========= 2024-05-23 16:22:00 =========
# +--------------------+-----+--------+--------------------+----------+---------+
# |               title|votes|comments|         probability|prediction|frontpage|
# +--------------------+-----+--------+--------------------+----------+---------+
# |DuckDuckGo broken...|   16|       8|[1.42271790956467...|       1.0|     true|
# +--------------------+-----+--------+--------------------+----------+---------+
#
# ========= 2024-05-23 16:22:10 =========
# +--------------------+-----+--------+--------------------+----------+---------+
# |               title|votes|comments|         probability|prediction|frontpage|
# +--------------------+-----+--------+--------------------+----------+---------+
# |  PrototypeJS (2015)|    1|       0|[0.97979827721086...|       0.0|    false|
# |The Privacy Smart...|    1|       0|[0.97926213831788...|       0.0|    false|
# |M2dir: Treating m...|    3|       0|[0.88316265187408...|       0.0|     true|
# |Hershey sued for ...|    1|       0|[0.94306426033530...|       0.0|    false|
# +--------------------+-----+--------+--------------------+----------+---------+
#
# ========= 2024-05-23 16:22:20 =========
# +--------------------+-----+--------+--------------------+----------+---------+
# |               title|votes|comments|         probability|prediction|frontpage|
# +--------------------+-----+--------+--------------------+----------+---------+
# |Lawyers say OpenA...|    1|       0|[0.98513675911601...|       0.0|    false|
# |Do cheating tools...|    1|       0|[0.96254127697960...|       0.0|    false|
# |Human sacrifice e...|    1|       0|[0.96616109869636...|       0.0|    false|
# |Databases Are Fal...|    1|       0|[0.96775608305726...|       0.0|    false|
# +--------------------+-----+--------+--------------------+----------+---------+
#
# ========= 2024-05-23 16:22:30 =========
# +--------------------+-----+--------+--------------------+----------+---------+
# |               title|votes|comments|         probability|prediction|frontpage|
# +--------------------+-----+--------+--------------------+----------+---------+
# |How secure is Sec...|    3|       0|[0.87858490442568...|       0.0|     true|
# |The traditional "...|    1|       0|[0.95950983329578...|       0.0|    false|
# |Typography for La...|    1|       0|[0.98607266194428...|       0.0|    false|
# +--------------------+-----+--------+--------------------+----------+---------+
#
# ========= 2024-05-23 16:22:40 =========
# +--------------------+-----+--------+--------------------+----------+---------+
# |               title|votes|comments|         probability|prediction|frontpage|
# +--------------------+-----+--------+--------------------+----------+---------+
# |Mapping the Mind ...|    1|       0|[0.97008696763004...|       0.0|    false|
# |Mathematician/Art...|    1|       0|[0.97480597569753...|       0.0|    false|
# |Life extensions v...|    1|       0|[0.97175541022276...|       0.0|    false|
# |Humane AI Pin is ...|    1|       0|[0.96148481298822...|       0.0|    false|
# +--------------------+-----+--------+--------------------+----------+---------+
#
# ========= 2024-05-23 16:22:50 =========
# +--------------------+-----+--------+--------------------+----------+---------+
# |               title|votes|comments|         probability|prediction|frontpage|
# +--------------------+-----+--------+--------------------+----------+---------+
# |Product Rocket (S...|    1|       0|[0.96272447630112...|       0.0|    false|
# |     Egg of Columbus|    1|       0|[0.98176282997266...|       0.0|    false|
# |The Economics of ...|    1|       0|[0.98554620130698...|       0.0|    false|
# +--------------------+-----+--------+--------------------+----------+---------+
#
# ========= 2024-05-23 16:23:00 =========
# +--------------------+-----+--------+--------------------+----------+---------+
# |               title|votes|comments|         probability|prediction|frontpage|
# +--------------------+-----+--------+--------------------+----------+---------+
# |KotlinConf 2024 K...|    1|       0|[0.95338009075989...|       0.0|    false|
# |I stumbled upon L...|    4|       0|[0.61598920569797...|       0.0|     true|
# |Show HN: Data sec...|    2|       0|[0.97191996109921...|       0.0|    false|
# +--------------------+-----+--------+--------------------+----------+---------+
#
# ========= 2024-05-23 16:23:10 =========
# +--------------------+-----+--------+--------------------+----------+---------+
# |               title|votes|comments|         probability|prediction|frontpage|
# +--------------------+-----+--------+--------------------+----------+---------+
# |Township Small Bu...|    1|       0|[0.96818414045875...|       0.0|    false|
# |Apple Wi-Fi Posit...|    4|       0|[0.68889188780147...|       0.0|     true|
# |Tour-de-Babel (2006)|    2|       0|[0.91749563043069...|       0.0|    false|
# |OpenAI does a dea...|    1|       0|[0.97178872194451...|       0.0|    false|
# +--------------------+-----+--------+--------------------+----------+---------+
#
# ========= 2024-05-23 16:23:20 =========
# +--------------------+-----+--------+--------------------+----------+---------+
# |               title|votes|comments|         probability|prediction|frontpage|
# +--------------------+-----+--------+--------------------+----------+---------+
# |Dutch police trac...|    1|       0|[0.97469398724632...|       0.0|    false|
# |China creates LLM...|    2|       0|[0.87247004048178...|       0.0|    false|
# |People shouldn't ...|    2|       0|[0.87126892027863...|       0.0|    false|
# +--------------------+-----+--------+--------------------+----------+---------+
# ========= 2024-05-23 16:23:30 =========
# +--------------------+-----+--------+--------------------+----------+---------+
# |               title|votes|comments|         probability|prediction|frontpage|
# +--------------------+-----+--------+--------------------+----------+---------+
# |Last Chance to Ge...|    2|       0|[0.95728307579888...|       0.0|    false|
# |QDirStat – Linux ...|    1|       0|[0.96204090595746...|       0.0|    false|
# |Google, Pizza, an...|    1|       0|[0.98021679438693...|       0.0|    false|
# +--------------------+-----+--------+--------------------+----------+---------+
#
# ========= 2024-05-23 16:23:40 =========
# +--------------------+-----+--------+--------------------+----------+---------+
# |               title|votes|comments|         probability|prediction|frontpage|
# +--------------------+-----+--------+--------------------+----------+---------+
# |Refining Discord'...|    1|       0|[0.97279481264891...|       0.0|    false|
# |Biden Keeps Passi...|    1|       0|[0.98524973226848...|       0.0|    false|
# |Microsoft Bing Se...|    6|       0|[0.24672313649938...|       1.0|     true|
# +--------------------+-----+--------+--------------------+----------+---------+
#
# ========= 2024-05-23 16:26:40 =========
# +--------------------+-----+--------+--------------------+----------+---------+
# |               title|votes|comments|         probability|prediction|frontpage|
# +--------------------+-----+--------+--------------------+----------+---------+
# |Bark Air – Airlin...|    1|       0|[0.95884196904569...|       0.0|    false|
# +--------------------+-----+--------+--------------------+----------+---------+
#
# ========= 2024-05-23 16:28:50 =========
# +--------------------+-----+--------+--------------------+----------+---------+
# |               title|votes|comments|         probability|prediction|frontpage|
# +--------------------+-----+--------+--------------------+----------+---------+
# |John Deere now co...|    3|       2|[0.84735865708361...|       0.0|     true|
# +--------------------+-----+--------+--------------------+----------+---------+
#
# ========= 2024-05-23 16:30:50 =========
# +--------------------+-----+--------+--------------------+----------+---------+
# |               title|votes|comments|         probability|prediction|frontpage|
# +--------------------+-----+--------+--------------------+----------+---------+
# |Sourcehut: Collec...|    1|       0|[0.96690197165400...|       0.0|    false|
# |    Bing.com Is Down|    2|       0|[0.94257824621181...|       0.0|    false|
# +--------------------+-----+--------+--------------------+----------+---------+
#
# ========= 2024-05-23 16:34:00 =========
# +--------------------+-----+--------+--------------------+----------+---------+
# |               title|votes|comments|         probability|prediction|frontpage|
# +--------------------+-----+--------+--------------------+----------+---------+
# |Liquid Death Reje...|    1|       0|[0.98225326397604...|       0.0|    false|
# +--------------------+-----+--------+--------------------+----------+---------+
#
# ========= 2024-05-23 16:41:00 =========
# +--------------------+-----+--------+--------------------+----------+---------+
# |               title|votes|comments|         probability|prediction|frontpage|
# +--------------------+-----+--------+--------------------+----------+---------+
# |Comparison of Fil...|    1|       2|[0.97646487479265...|       0.0|    false|
# +--------------------+-----+--------+--------------------+----------+---------+
#
# ========= 2024-05-23 16:44:00 =========
# +--------------------+-----+--------+--------------------+----------+---------+
# |               title|votes|comments|         probability|prediction|frontpage|
# +--------------------+-----+--------+--------------------+----------+---------+
# |Power/Performance...|    1|       0|[0.97042332855833...|       0.0|    false|
# +--------------------+-----+--------+--------------------+----------+---------+
#
# ========= 2024-05-23 16:46:00 =========
# +--------------------+-----+--------+--------------------+----------+---------+
# |               title|votes|comments|         probability|prediction|frontpage|
# +--------------------+-----+--------+--------------------+----------+---------+
# |The role of Dark ...|    1|       0|[0.97289076420574...|       0.0|    false|
# +--------------------+-----+--------+--------------------+----------+---------+
#
# ========= 2024-05-23 16:47:00 =========
# +--------------------+-----+--------+--------------------+----------+---------+
# |               title|votes|comments|         probability|prediction|frontpage|
# +--------------------+-----+--------+--------------------+----------+---------+
# |Retro writing 15 ...|    1|       0|[0.97022284355938...|       0.0|    false|
# +--------------------+-----+--------+--------------------+----------+---------+
#
# ========= 2024-05-23 16:48:10 =========
# +------------------+-----+--------+--------------------+----------+---------+
# |             title|votes|comments|         probability|prediction|frontpage|
# +------------------+-----+--------+--------------------+----------+---------+
# |Alberta Separatism|    1|       0|[0.97811386680908...|       0.0|    false|
# +------------------+-----+--------+--------------------+----------+---------+
#
# ========= 2024-05-23 16:49:10 =========
# +--------------------+-----+--------+--------------------+----------+---------+
# |               title|votes|comments|         probability|prediction|frontpage|
# +--------------------+-----+--------+--------------------+----------+---------+
# |Show HN: I Made a...|    1|       0|[0.98579381176335...|       0.0|    false|
# +--------------------+-----+--------+--------------------+----------+---------+
#
# ========= 2024-05-23 16:50:10 =========
# +--------------------+-----+--------+--------------------+----------+---------+
# |               title|votes|comments|         probability|prediction|frontpage|
# +--------------------+-----+--------+--------------------+----------+---------+
# |The academic lite...|    1|       0|[0.96377593410125...|       0.0|    false|
# +--------------------+-----+--------+--------------------+----------+---------+
#
# ========= 2024-05-23 16:54:20 =========
# +--------------------+-----+--------+--------------------+----------+---------+
# |               title|votes|comments|         probability|prediction|frontpage|
# +--------------------+-----+--------+--------------------+----------+---------+
# |EU's new tech law...|    2|       0|[0.81913256715160...|       0.0|    false|
# +--------------------+-----+--------+--------------------+----------+---------+
#
# ========= 2024-05-23 16:55:20 =========
# +--------------------+-----+--------+--------------------+----------+---------+
# |               title|votes|comments|         probability|prediction|frontpage|
# +--------------------+-----+--------+--------------------+----------+---------+
# |The Collapse Is C...|    3|       0|[0.83161916513294...|       0.0|    false|
# |It looks a lot li...|    3|       0|[0.66334024428295...|       0.0|     true|
# +--------------------+-----+--------+--------------------+----------+---------+
#
# ========= 2024-05-23 16:56:20 =========
# +--------------------+-----+--------+--------------------+----------+---------+
# |               title|votes|comments|         probability|prediction|frontpage|
# +--------------------+-----+--------+--------------------+----------+---------+
# |Generative Molecu...|    1|       0|[0.96508759355766...|       0.0|    false|
# +--------------------+-----+--------+--------------------+----------+---------+
#
# ========= 2024-05-23 16:57:30 =========
# +--------------------+-----+--------+--------------------+----------+---------+
# |               title|votes|comments|         probability|prediction|frontpage|
# +--------------------+-----+--------+--------------------+----------+---------+
# |What Rust Got Wro...|    1|       0|[0.97579957345205...|       0.0|    false|
# +--------------------+-----+--------+--------------------+----------+---------+
#
# ========= 2024-05-23 16:59:30 =========
# +--------------------+-----+--------+--------------------+----------+---------+
# |               title|votes|comments|         probability|prediction|frontpage|
# +--------------------+-----+--------+--------------------+----------+---------+
# |Celebrating Kotli...|    6|       0|[0.31690772646613...|       1.0|     true|
# +--------------------+-----+--------+--------------------+----------+---------+
# ========= 2024-05-23 17:04:30 =========
# +--------------------+-----+--------+--------------------+----------+---------+
# |               title|votes|comments|         probability|prediction|frontpage|
# +--------------------+-----+--------+--------------------+----------+---------+
# |High BMI linked t...|    2|       0|[0.93859069688369...|       0.0|    false|
# +--------------------+-----+--------+--------------------+----------+---------+
#
# ========= 2024-05-23 17:07:40 =========
# +------------------+-----+--------+--------------------+----------+---------+
# |             title|votes|comments|         probability|prediction|frontpage|
# +------------------+-----+--------+--------------------+----------+---------+
# |DuckDuckGo Is Down|    1|       0|[0.98648929052124...|       0.0|    false|
# +------------------+-----+--------+--------------------+----------+---------+
#
# ========= 2024-05-23 17:08:40 =========
# +--------------------+-----+--------+--------------------+----------+---------+
# |               title|votes|comments|         probability|prediction|frontpage|
# +--------------------+-----+--------+--------------------+----------+---------+
# |EU governments to...|    4|       0|[0.75058348159651...|       0.0|    false|
# +--------------------+-----+--------+--------------------+----------+---------+
#
# ========= 2024-05-23 17:08:50 =========
# +--------------------+-----+--------+--------------------+----------+---------+
# |               title|votes|comments|         probability|prediction|frontpage|
# +--------------------+-----+--------+--------------------+----------+---------+
# |Bing API is down,...|    7|       3|[0.19998449324967...|       1.0|     true|
# +--------------------+-----+--------+--------------------+----------+---------+
#
# ========= 2024-05-23 17:18:50 =========
# +--------------------+-----+--------+--------------------+----------+---------+
# |               title|votes|comments|         probability|prediction|frontpage|
# +--------------------+-----+--------+--------------------+----------+---------+
# |Show HN: Affordab...|    1|       0|[0.98427021688020...|       0.0|    false|
# +--------------------+-----+--------+--------------------+----------+---------+
#
# ========= 2024-05-23 17:19:00 =========
# +--------------------+-----+--------+--------------------+----------+---------+
# |               title|votes|comments|         probability|prediction|frontpage|
# +--------------------+-----+--------+--------------------+----------+---------+
# |Tabler Illustrati...|    2|       0|[0.88112109039106...|       0.0|    false|
# +--------------------+-----+--------+--------------------+----------+---------+

# %%
ssc_t.stop()
# Out:
# ----- Stopping... this may take a few seconds -----
